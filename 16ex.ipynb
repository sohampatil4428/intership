# %%
import pandas as pd

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# sepal.length    0.0
# sepal.width     0.0
# petal.length    0.0
# petal.width     0.0
# variety         0.0
# dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df[df['sepal.width']> 4]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 15           5.7          4.4           1.5          0.4  Setosa
# 32           5.2          4.1           1.5          0.1  Setosa
# 33           5.5          4.2           1.4          0.2  Setosa

# %%
df[df['petal.width']>1]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 50            7.0          3.2           4.7          1.4  Versicolor
# 51            6.4          3.2           4.5          1.5  Versicolor
# 52            6.9          3.1           4.9          1.5  Versicolor
# 53            5.5          2.3           4.0          1.3  Versicolor
# 54            6.5          2.8           4.6          1.5  Versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   Virginica
# 146           6.3          2.5           5.0          1.9   Virginica
# 147           6.5          3.0           5.2          2.0   Virginica
# 148           6.2          3.4           5.4          2.3   Virginica
# 149           5.9          3.0           5.1          1.8   Virginica
#
# [93 rows x 5 columns]

# %%
df[df['petal.width']>2]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# 114           5.8          2.8           5.1          2.4  Virginica
# 115           6.4          3.2           5.3          2.3  Virginica
# 117           7.7          3.8           6.7          2.2  Virginica
# 118           7.7          2.6           6.9          2.3  Virginica
# 120           6.9          3.2           5.7          2.3  Virginica
# 124           6.7          3.3           5.7          2.1  Virginica
# 128           6.4          2.8           5.6          2.1  Virginica
# 132           6.4          2.8           5.6          2.2  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# 136           6.3          3.4           5.6          2.4  Virginica
# 139           6.9          3.1           5.4          2.1  Virginica
# 140           6.7          3.1           5.6          2.4  Virginica
# 141           6.9          3.1           5.1          2.3  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='sepal.length',y='petal.length',data=df)
plt.show()

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
y=df[['sepal.length']]

# %%
x=df[['sepal.width']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,text_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,text_size=0.3)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\inspect.py:3267, in Signature.bind(self, *args, **kwargs)
#    3262 def bind(self, /, *args, **kwargs):
#    3263     """Get a BoundArguments object, that maps the passed `args`
#    3264     and `kwargs` to the function's signature.  Raises `TypeError`
#    3265     if the passed arguments can not be bound.
#    3266     """
# -> 3267     return self._bind(args, kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\inspect.py:3256, in Signature._bind(self, args, kwargs, partial)
#    3246         raise TypeError(
#    3247             'got some positional-only arguments passed as '
#    3248             'keyword arguments: {arg!r}'.format(
#    (...)   3253             ),
#    3254         )
#    3255     else:
# -> 3256         raise TypeError(
#    3257             'got an unexpected keyword argument {arg!r}'.format(
#    3258                 arg=next(iter(kwargs))))
#    3260 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'text_size'
