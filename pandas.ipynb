# %%
import pandas as pd

# %%
data=pd.read_csv("studata.csv")
data
# Out:
#    rollno stu_name  stu_mark
# 0       1    soham        90
# 1       2  shubhzz        95
# 2       3    omkar        92
# 3       4   vedant        90
# 4       5    rohit        85
# 5       6    kunal        70

# %%
import matplotlib.pyplot as plt

x=('stu_name')
y=('stu_mark')

# %%
plt.plot()
plt.Figure(figsize=(2,4))
plt.title("line chart")
x=[1,2,3,4,5]
y=[50,60,70,80,90]
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.grid()

plt.show()

# %%
data=pd.read_csv("studata.csv")
data
# Out:
#    rollno stu_name  stu_mark
# 0       1    soham        90
# 1       2  shubhzz        95
# 2       3    omkar        92
# 3       4   vedant        90
# 4       5    rohit        85
# 5       6    kunal        70

# %%
plt.plot(data["stu_mark"],color="black",marker="o",linestyle = "--") 
plt.xlabel(data["stu_name"])
plt.ylabel(data["stu_mark"])
plt.grid()
plt.show()

# %%
#histogram
plt.hist(data["stu_mark"])
plt.show()

# %%
#boxplot:
plt.boxplot(data["stu_mark"])
plt.show()
