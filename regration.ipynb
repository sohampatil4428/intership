# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
data=pd.read_csv("regration.csv")
data
# Out:
#    object  price
# 0       1      5
# 1       2     10
# 2       3     20
# 3       4     10

# %%
# %matplotlib inline
plt.xlabel("object_name")
plt.ylabel("object_price")
plt.grid()
plt.scatter(data.object,data.price,color="red",marker='o')

# %%
reg=linear_model.LinearRegression()
reg.fit(data[["object"]],data.price)
# Out:
# LinearRegression()

# %%
reg.predict(1)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 reg.predict(1)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# ...
